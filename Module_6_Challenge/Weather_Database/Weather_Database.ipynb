# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform (low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform (low = -180.000, high = 180.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 730

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]       
        city_desc = city_weather["weather"][0]["description"]    
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_desc})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | faanui
# Processing Record 2 of Set 1 | saint-philippe
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | victoria
# Processing Record 5 of Set 1 | mahebourg
# Processing Record 6 of Set 1 | thompson
# Processing Record 7 of Set 1 | emerald
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | safranbolu
# Processing Record 12 of Set 1 | avarua
# Processing Record 13 of Set 1 | rocha
# Processing Record 14 of Set 1 | castro
# Processing Record 15 of Set 1 | lensk
# Processing Record 16 of Set 1 | paamiut
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | alyangula
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | carnarvon
# Processing Record 24 of Set 1 | mnogovershinnyy
# Processing Record 25 of Set 1 | liwale
# Processing Record 26 of Set 1 | palana
# Processing Record 27 of Set 1 | geraldton
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | hithadhoo
# Processing Record 30 of Set 1 | tasiilaq
# Processing Record 31 of Set 1 | port hardy
# Processing Record 32 of Set 1 | pevek
# Processing Record 33 of Set 1 | chuy
# Processing Record 34 of Set 1 | bilma
# Processing Record 35 of Set 1 | kashi
# Processing Record 36 of Set 1 | klaksvik
# Processing Record 37 of Set 1 | jurm
# Processing Record 38 of Set 1 | tuktoyaktuk
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | bambous virieux
# Processing Record 41 of Set 1 | norsup
# Processing Record 42 of Set 1 | rio gallegos
# Processing Record 43 of Set 1 | lincoln
# Processing Record 44 of Set 1 | iqaluit
# Processing Record 45 of Set 1 | porto belo
# Processing Record 46 of Set 1 | kabelvag
# Processing Record 47 of Set 1 | bathsheba
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | ushuaia
# Processing Record 1 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 2 | nikolskoye
# Processing Record 3 of Set 2 | san luis
# Processing Record 4 of Set 2 | rikitea
# Processing Record 5 of Set 2 | madras
# Processing Record 6 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 2 | ketchikan
# Processing Record 8 of Set 2 | hilo
# Processing Record 9 of Set 2 | albany
# Processing Record 10 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 2 | longyearbyen
# Processing Record 12 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 2 | caraquet
# Processing Record 14 of Set 2 | nelson bay
# Processing Record 15 of Set 2 | praia da vitoria
# Processing Record 16 of Set 2 | hobart
# Processing Record 17 of Set 2 | ribeira grande
# Processing Record 18 of Set 2 | port blair
# Processing Record 19 of Set 2 | sahrak
# City not found. Skipping...
# Processing Record 20 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 2 | ugoofaaru
# Processing Record 22 of Set 2 | tura
# Processing Record 23 of Set 2 | san patricio
# Processing Record 24 of Set 2 | qaanaaq
# Processing Record 25 of Set 2 | butaritari
# Processing Record 26 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 2 | luderitz
# Processing Record 28 of Set 2 | new norfolk
# Processing Record 29 of Set 2 | nizhniy baskunchak
# Processing Record 30 of Set 2 | sonoita
# Processing Record 31 of Set 2 | mataura
# Processing Record 32 of Set 2 | ahuimanu
# Processing Record 33 of Set 2 | northam
# Processing Record 34 of Set 2 | bam
# Processing Record 35 of Set 2 | milingimbi
# City not found. Skipping...
# Processing Record 36 of Set 2 | samarai
# Processing Record 37 of Set 2 | teya
# Processing Record 38 of Set 2 | port alfred
# Processing Record 39 of Set 2 | khani
# Processing Record 40 of Set 2 | kutum
# Processing Record 41 of Set 2 | khatanga
# Processing Record 42 of Set 2 | kremasti
# Processing Record 43 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 2 | katsuura
# Processing Record 45 of Set 2 | bontang
# Processing Record 46 of Set 2 | zuwarah
# Processing Record 47 of Set 2 | rio tuba
# Processing Record 48 of Set 2 | chino valley
# Processing Record 49 of Set 2 | north bend
# Processing Record 50 of Set 2 | cabo san lucas
# Processing Record 1 of Set 3 | vicuna
# Processing Record 2 of Set 3 | den helder
# Processing Record 3 of Set 3 | port macquarie
# Processing Record 4 of Set 3 | portland
# Processing Record 5 of Set 3 | surt
# Processing Record 6 of Set 3 | los llanos de aridane
# Processing Record 7 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 8 of Set 3 | kedrovyy
# Processing Record 9 of Set 3 | arraial do cabo
# Processing Record 10 of Set 3 | narsaq
# Processing Record 11 of Set 3 | ambikapur
# Processing Record 12 of Set 3 | moussoro
# Processing Record 13 of Set 3 | avera
# Processing Record 14 of Set 3 | cockburn town
# Processing Record 15 of Set 3 | conde
# Processing Record 16 of Set 3 | mayumba
# Processing Record 17 of Set 3 | severo-kurilsk
# Processing Record 18 of Set 3 | tilichiki
# Processing Record 19 of Set 3 | mar del plata
# Processing Record 20 of Set 3 | flin flon
# Processing Record 21 of Set 3 | havre
# Processing Record 22 of Set 3 | kiama
# Processing Record 23 of Set 3 | yulara
# Processing Record 24 of Set 3 | jinchang
# Processing Record 25 of Set 3 | tautira
# Processing Record 26 of Set 3 | nantucket
# Processing Record 27 of Set 3 | porto novo
# Processing Record 28 of Set 3 | ewa beach
# Processing Record 29 of Set 3 | shellbrook
# Processing Record 30 of Set 3 | lidorikion
# City not found. Skipping...
# Processing Record 31 of Set 3 | shakhovskaya
# Processing Record 32 of Set 3 | kurumkan
# Processing Record 33 of Set 3 | torbay
# Processing Record 34 of Set 3 | verkh-chebula
# Processing Record 35 of Set 3 | trinidad
# Processing Record 36 of Set 3 | yabassi
# Processing Record 37 of Set 3 | wakkanai
# Processing Record 38 of Set 3 | linhares
# Processing Record 39 of Set 3 | lagoa
# Processing Record 40 of Set 3 | cap-aux-meules
# Processing Record 41 of Set 3 | le port
# Processing Record 42 of Set 3 | muromtsevo
# Processing Record 43 of Set 3 | georgetown
# Processing Record 44 of Set 3 | saskylakh
# Processing Record 45 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 46 of Set 3 | rabat
# Processing Record 47 of Set 3 | amnat charoen
# Processing Record 48 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 49 of Set 3 | buariki
# City not found. Skipping...
# Processing Record 50 of Set 3 | porbandar
# Processing Record 1 of Set 4 | sitka
# Processing Record 2 of Set 4 | kahului
# Processing Record 3 of Set 4 | brajrajnagar
# City not found. Skipping...
# Processing Record 4 of Set 4 | narasannapeta
# Processing Record 5 of Set 4 | buchanan
# Processing Record 6 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 4 | kenmare
# Processing Record 8 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 9 of Set 4 | caravelas
# Processing Record 10 of Set 4 | adrar
# Processing Record 11 of Set 4 | zonguldak
# Processing Record 12 of Set 4 | atar
# Processing Record 13 of Set 4 | dikson
# Processing Record 14 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 4 | rawson
# Processing Record 16 of Set 4 | lebu
# Processing Record 17 of Set 4 | east london
# Processing Record 18 of Set 4 | yenagoa
# Processing Record 19 of Set 4 | salalah
# Processing Record 20 of Set 4 | burnie
# Processing Record 21 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 22 of Set 4 | zabid
# Processing Record 23 of Set 4 | port hedland
# Processing Record 24 of Set 4 | thasra
# Processing Record 25 of Set 4 | beira
# Processing Record 26 of Set 4 | forquilhinha
# Processing Record 27 of Set 4 | rojhan
# Processing Record 28 of Set 4 | nalut
# Processing Record 29 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 30 of Set 4 | bubaque
# Processing Record 31 of Set 4 | nanortalik
# Processing Record 32 of Set 4 | tabou
# Processing Record 33 of Set 4 | manzhouli
# Processing Record 34 of Set 4 | lavrentiya
# Processing Record 35 of Set 4 | kamenka
# Processing Record 36 of Set 4 | mukhen
# Processing Record 37 of Set 4 | vrutky
# Processing Record 38 of Set 4 | barrow
# Processing Record 39 of Set 4 | praia
# Processing Record 40 of Set 4 | belyy yar
# Processing Record 41 of Set 4 | marieville
# Processing Record 42 of Set 4 | baisha
# Processing Record 43 of Set 4 | neverkino
# Processing Record 44 of Set 4 | sinkat
# City not found. Skipping...
# Processing Record 45 of Set 4 | ambilobe
# Processing Record 46 of Set 4 | liaoyang
# Processing Record 47 of Set 4 | mabaruma
# Processing Record 48 of Set 4 | quatre cocos
# Processing Record 49 of Set 4 | nanton
# Processing Record 50 of Set 4 | dunedin
# Processing Record 1 of Set 5 | port elizabeth
# Processing Record 2 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 5 | njombe
# Processing Record 4 of Set 5 | coquimbo
# Processing Record 5 of Set 5 | vanimo
# Processing Record 6 of Set 5 | frome
# Processing Record 7 of Set 5 | coihaique
# Processing Record 8 of Set 5 | atuona
# Processing Record 9 of Set 5 | saint-augustin
# Processing Record 10 of Set 5 | port augusta
# Processing Record 11 of Set 5 | gunjur
# Processing Record 12 of Set 5 | pachino
# Processing Record 13 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 5 | itaqui
# Processing Record 15 of Set 5 | kenora
# Processing Record 16 of Set 5 | aktas
# Processing Record 17 of Set 5 | taltal
# Processing Record 18 of Set 5 | airai
# Processing Record 19 of Set 5 | sangar
# Processing Record 20 of Set 5 | clyde river
# Processing Record 21 of Set 5 | shelburne
# Processing Record 22 of Set 5 | muncie
# Processing Record 23 of Set 5 | tateyama
# Processing Record 24 of Set 5 | hamilton
# Processing Record 25 of Set 5 | pa daet
# Processing Record 26 of Set 5 | ponta do sol
# Processing Record 27 of Set 5 | manggar
# Processing Record 28 of Set 5 | tarimbaro
# Processing Record 29 of Set 5 | catabola
# Processing Record 30 of Set 5 | sobolevo
# Processing Record 31 of Set 5 | namibe
# Processing Record 32 of Set 5 | half moon bay
# Processing Record 33 of Set 5 | palasa
# Processing Record 34 of Set 5 | wajima
# Processing Record 35 of Set 5 | bengkulu
# Processing Record 36 of Set 5 | klyuchevskiy
# Processing Record 37 of Set 5 | nemuro
# Processing Record 38 of Set 5 | malayal
# Processing Record 39 of Set 5 | anzio
# Processing Record 40 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 5 | aklavik
# Processing Record 42 of Set 5 | sao joao da barra
# Processing Record 43 of Set 5 | marsh harbour
# Processing Record 44 of Set 5 | chapais
# Processing Record 45 of Set 5 | valdivia
# Processing Record 46 of Set 5 | orissaare
# Processing Record 47 of Set 5 | asau
# Processing Record 48 of Set 5 | satuk
# Processing Record 49 of Set 5 | santiago del estero
# Processing Record 50 of Set 5 | cayenne
# Processing Record 1 of Set 6 | omsukchan
# Processing Record 2 of Set 6 | eslov
# Processing Record 3 of Set 6 | poum
# Processing Record 4 of Set 6 | nome
# Processing Record 5 of Set 6 | alice springs
# Processing Record 6 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 6 | ahipara
# Processing Record 8 of Set 6 | cah ab
# City not found. Skipping...
# Processing Record 9 of Set 6 | henties bay
# Processing Record 10 of Set 6 | hofn
# Processing Record 11 of Set 6 | marsa matruh
# Processing Record 12 of Set 6 | auki
# Processing Record 13 of Set 6 | umm ruwabah
# City not found. Skipping...
# Processing Record 14 of Set 6 | ilulissat
# Processing Record 15 of Set 6 | nabire
# Processing Record 16 of Set 6 | provideniya
# Processing Record 17 of Set 6 | araouane
# Processing Record 18 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 19 of Set 6 | road town
# Processing Record 20 of Set 6 | sao filipe
# Processing Record 21 of Set 6 | petropavl
# Processing Record 22 of Set 6 | crawfordsville
# Processing Record 23 of Set 6 | vardo
# Processing Record 24 of Set 6 | oussouye
# Processing Record 25 of Set 6 | churapcha
# Processing Record 26 of Set 6 | fortuna
# Processing Record 27 of Set 6 | kuching
# Processing Record 28 of Set 6 | touros
# Processing Record 29 of Set 6 | dingle
# Processing Record 30 of Set 6 | marzuq
# Processing Record 31 of Set 6 | ust-omchug
# Processing Record 32 of Set 6 | gangotri
# City not found. Skipping...
# Processing Record 33 of Set 6 | korla
# Processing Record 34 of Set 6 | inirida
# Processing Record 35 of Set 6 | seymchan
# Processing Record 36 of Set 6 | benghazi
# Processing Record 37 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 38 of Set 6 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 39 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 6 | raga
# Processing Record 41 of Set 6 | colac
# Processing Record 42 of Set 6 | borogontsy
# Processing Record 43 of Set 6 | tskneti
# Processing Record 44 of Set 6 | gopichettipalaiyam
# City not found. Skipping...
# Processing Record 45 of Set 6 | deputatskiy
# Processing Record 46 of Set 6 | castelo do piaui
# Processing Record 47 of Set 6 | zeerust
# Processing Record 48 of Set 6 | taunggyi
# Processing Record 49 of Set 6 | general roca
# Processing Record 50 of Set 6 | kadaya
# Processing Record 1 of Set 7 | garwolin
# Processing Record 2 of Set 7 | meulaboh
# Processing Record 3 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 4 of Set 7 | lerwick
# Processing Record 5 of Set 7 | kaitangata
# Processing Record 6 of Set 7 | abiy adi
# City not found. Skipping...
# Processing Record 7 of Set 7 | morondava
# Processing Record 8 of Set 7 | haines junction
# Processing Record 9 of Set 7 | okhotsk
# Processing Record 10 of Set 7 | sakassou
# Processing Record 11 of Set 7 | margate
# Processing Record 12 of Set 7 | esperance
# Processing Record 13 of Set 7 | cofradia
# Processing Record 14 of Set 7 | neyshabur
# Processing Record 15 of Set 7 | hasaki
# Processing Record 16 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 7 | waw
# Processing Record 18 of Set 7 | upernavik
# Processing Record 19 of Set 7 | payo
# Processing Record 20 of Set 7 | vestmannaeyjar
# Processing Record 21 of Set 7 | rolim de moura
# City not found. Skipping...
# Processing Record 22 of Set 7 | vera cruz
# Processing Record 23 of Set 7 | zhanakorgan
# Processing Record 24 of Set 7 | dalbandin
# Processing Record 25 of Set 7 | sembe
# Processing Record 26 of Set 7 | shiyan
# Processing Record 27 of Set 7 | kushalnagar
# Processing Record 28 of Set 7 | hobyo
# Processing Record 29 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 7 | port lincoln
# Processing Record 31 of Set 7 | vila
# Processing Record 32 of Set 7 | sundargarh
# Processing Record 33 of Set 7 | banda aceh
# Processing Record 34 of Set 7 | jalu
# Processing Record 35 of Set 7 | norman wells
# Processing Record 36 of Set 7 | palanpur
# Processing Record 37 of Set 7 | kungurtug
# Processing Record 38 of Set 7 | puerto baquerizo moreno
# Processing Record 39 of Set 7 | sterling
# Processing Record 40 of Set 7 | baculin
# Processing Record 41 of Set 7 | richards bay
# Processing Record 42 of Set 7 | roma
# Processing Record 43 of Set 7 | cherskiy
# Processing Record 44 of Set 7 | mount isa
# Processing Record 45 of Set 7 | lompoc
# Processing Record 46 of Set 7 | panjab
# Processing Record 47 of Set 7 | maibong
# Processing Record 48 of Set 7 | bairnsdale
# Processing Record 49 of Set 7 | nouakchott
# Processing Record 50 of Set 7 | peace river
# Processing Record 1 of Set 8 | abha
# Processing Record 2 of Set 8 | nador
# Processing Record 3 of Set 8 | tabas
# Processing Record 4 of Set 8 | capitao poco
# Processing Record 5 of Set 8 | roald
# Processing Record 6 of Set 8 | kenai
# Processing Record 7 of Set 8 | bell ville
# Processing Record 8 of Set 8 | beloha
# Processing Record 9 of Set 8 | vuktyl
# Processing Record 10 of Set 8 | souillac
# Processing Record 11 of Set 8 | santa marta de tormes
# Processing Record 12 of Set 8 | bairiki
# Processing Record 13 of Set 8 | businga
# Processing Record 14 of Set 8 | udachnyy
# Processing Record 15 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 8 | vila velha
# Processing Record 17 of Set 8 | xining
# Processing Record 18 of Set 8 | talnakh
# Processing Record 19 of Set 8 | maceio
# Processing Record 20 of Set 8 | ngunguru
# Processing Record 21 of Set 8 | kodiak
# Processing Record 22 of Set 8 | upata
# Processing Record 23 of Set 8 | broome
# Processing Record 24 of Set 8 | pombas
# Processing Record 25 of Set 8 | puerto escondido
# Processing Record 26 of Set 8 | glencoe
# Processing Record 27 of Set 8 | wum
# Processing Record 28 of Set 8 | pontianak
# Processing Record 29 of Set 8 | chipinge
# Processing Record 30 of Set 8 | grindavik
# Processing Record 31 of Set 8 | miri
# Processing Record 32 of Set 8 | mareeba
# Processing Record 33 of Set 8 | melilla
# Processing Record 34 of Set 8 | port hueneme
# Processing Record 35 of Set 8 | singapore
# Processing Record 36 of Set 8 | del rio
# Processing Record 37 of Set 8 | salisbury
# Processing Record 38 of Set 8 | peleduy
# Processing Record 39 of Set 8 | faya
# Processing Record 40 of Set 8 | luba
# Processing Record 41 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 8 | naze
# Processing Record 43 of Set 8 | ordynskoye
# Processing Record 44 of Set 8 | culaba
# Processing Record 45 of Set 8 | gimli
# Processing Record 46 of Set 8 | mgandu
# Processing Record 47 of Set 8 | mbini
# Processing Record 48 of Set 8 | quelimane
# Processing Record 49 of Set 8 | leningradskiy
# Processing Record 50 of Set 8 | portobelo
# Processing Record 1 of Set 9 | ancud
# Processing Record 2 of Set 9 | mogadishu
# Processing Record 3 of Set 9 | prado
# Processing Record 4 of Set 9 | nizwa
# Processing Record 5 of Set 9 | saint-georges
# Processing Record 6 of Set 9 | teguise
# Processing Record 7 of Set 9 | sakakah
# Processing Record 8 of Set 9 | gat
# Processing Record 9 of Set 9 | panguipulli
# Processing Record 10 of Set 9 | bandar-e lengeh
# Processing Record 11 of Set 9 | cabedelo
# Processing Record 12 of Set 9 | broken hill
# Processing Record 13 of Set 9 | ukiah
# Processing Record 14 of Set 9 | yining
# Processing Record 15 of Set 9 | riyadh
# Processing Record 16 of Set 9 | harper
# Processing Record 17 of Set 9 | regeneracao
# Processing Record 18 of Set 9 | el badari
# City not found. Skipping...
# Processing Record 19 of Set 9 | birjand
# Processing Record 20 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 21 of Set 9 | snezhnogorsk
# Processing Record 22 of Set 9 | buala
# Processing Record 23 of Set 9 | dinsor
# City not found. Skipping...
# Processing Record 24 of Set 9 | alberton
# Processing Record 25 of Set 9 | saldanha
# Processing Record 26 of Set 9 | nagireddipalle
# City not found. Skipping...
# Processing Record 27 of Set 9 | palauig
# Processing Record 28 of Set 9 | tepotzotlan
# Processing Record 29 of Set 9 | oshnaviyeh
# Processing Record 30 of Set 9 | chokurdakh
# Processing Record 31 of Set 9 | lata
# Processing Record 32 of Set 9 | pacific grove
# Processing Record 33 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 9 | uige
# Processing Record 35 of Set 9 | vaitape
# Processing Record 36 of Set 9 | tiksi
# Processing Record 37 of Set 9 | pescia
# Processing Record 38 of Set 9 | fillmore
# Processing Record 39 of Set 9 | banjar
# Processing Record 40 of Set 9 | chara
# Processing Record 41 of Set 9 | sibolga
# Processing Record 42 of Set 9 | uarini
# Processing Record 43 of Set 9 | brus laguna
# Processing Record 44 of Set 9 | kuala terengganu
# Processing Record 45 of Set 9 | kruisfontein
# Processing Record 46 of Set 9 | vila franca do campo
# Processing Record 47 of Set 9 | santa pola
# Processing Record 48 of Set 9 | nyurba
# Processing Record 49 of Set 9 | izumo
# Processing Record 50 of Set 9 | kaniama
# Processing Record 1 of Set 10 | frankfort
# Processing Record 2 of Set 10 | bulawayo
# Processing Record 3 of Set 10 | sistranda
# Processing Record 4 of Set 10 | hambantota
# Processing Record 5 of Set 10 | suda
# Processing Record 6 of Set 10 | hay river
# Processing Record 7 of Set 10 | anderson
# Processing Record 8 of Set 10 | kitob
# Processing Record 9 of Set 10 | tuatapere
# Processing Record 10 of Set 10 | mandiana
# Processing Record 11 of Set 10 | xinpu
# Processing Record 12 of Set 10 | college
# Processing Record 13 of Set 10 | yanchukan
# City not found. Skipping...
# Processing Record 14 of Set 10 | noumea
# Processing Record 15 of Set 10 | umm lajj
# Processing Record 16 of Set 10 | bowen
# Processing Record 17 of Set 10 | rio pardo de minas
# Processing Record 18 of Set 10 | rio grande
# Processing Record 19 of Set 10 | murray
# Processing Record 20 of Set 10 | pamanukan
# Processing Record 21 of Set 10 | killarney
# Processing Record 22 of Set 10 | ushumun
# Processing Record 23 of Set 10 | giddalur
# Processing Record 24 of Set 10 | te anau
# Processing Record 25 of Set 10 | matagami
# Processing Record 26 of Set 10 | pottsville
# Processing Record 27 of Set 10 | miramar
# Processing Record 28 of Set 10 | segovia
# Processing Record 29 of Set 10 | anadyr
# Processing Record 30 of Set 10 | erie
# Processing Record 31 of Set 10 | revda
# Processing Record 32 of Set 10 | balkanabat
# Processing Record 33 of Set 10 | palembang
# Processing Record 34 of Set 10 | nakamura
# Processing Record 35 of Set 10 | kadipaten
# Processing Record 36 of Set 10 | brae
# Processing Record 37 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 10 | puerto palomas
# Processing Record 39 of Set 10 | namatanai
# Processing Record 40 of Set 10 | mahajanga
# Processing Record 41 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 42 of Set 10 | fort nelson
# Processing Record 43 of Set 10 | pisco
# Processing Record 44 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 10 | eraclea
# Processing Record 46 of Set 10 | hailar
# Processing Record 47 of Set 10 | beringovskiy
# Processing Record 48 of Set 10 | hami
# Processing Record 49 of Set 10 | flinders
# Processing Record 50 of Set 10 | maxixe
# Processing Record 1 of Set 11 | tir pol
# City not found. Skipping...
# Processing Record 2 of Set 11 | villarrubia de los ojos
# Processing Record 3 of Set 11 | alexandria
# Processing Record 4 of Set 11 | lashio
# Processing Record 5 of Set 11 | quisqueya
# Processing Record 6 of Set 11 | yar-sale
# Processing Record 7 of Set 11 | codrington
# Processing Record 8 of Set 11 | moen
# Processing Record 9 of Set 11 | charleston
# Processing Record 10 of Set 11 | sassandra
# Processing Record 11 of Set 11 | havoysund
# Processing Record 12 of Set 11 | lahij
# Processing Record 13 of Set 11 | cidreira
# Processing Record 14 of Set 11 | amlagora
# Processing Record 15 of Set 11 | yatou
# Processing Record 16 of Set 11 | dingzhou
# Processing Record 17 of Set 11 | gazanjyk
# Processing Record 18 of Set 11 | tazovskiy
# Processing Record 19 of Set 11 | manokwari
# Processing Record 20 of Set 11 | hailey
# Processing Record 21 of Set 11 | lively
# Processing Record 22 of Set 11 | luwuk
# Processing Record 23 of Set 11 | charlestown
# Processing Record 24 of Set 11 | kavieng
# Processing Record 25 of Set 11 | opuwo
# Processing Record 26 of Set 11 | krasnoarmeysk
# Processing Record 27 of Set 11 | yerbogachen
# Processing Record 28 of Set 11 | garowe
# Processing Record 29 of Set 11 | shingu
# Processing Record 30 of Set 11 | socorro
# Processing Record 31 of Set 11 | knysna
# Processing Record 32 of Set 11 | takayama
# Processing Record 33 of Set 11 | saint-jean-de-braye
# Processing Record 34 of Set 11 | haifa
# Processing Record 35 of Set 11 | launceston
# Processing Record 36 of Set 11 | fonte boa
# Processing Record 37 of Set 11 | sur
# Processing Record 38 of Set 11 | lake charles
# Processing Record 39 of Set 11 | alofi
# Processing Record 40 of Set 11 | huarmey
# Processing Record 41 of Set 11 | mount gambier
# Processing Record 42 of Set 11 | boyolangu
# Processing Record 43 of Set 11 | kapit
# Processing Record 44 of Set 11 | palmer
# Processing Record 45 of Set 11 | beisfjord
# Processing Record 46 of Set 11 | fairbanks
# Processing Record 47 of Set 11 | guerrero negro
# Processing Record 48 of Set 11 | san felipe del progreso
# Processing Record 49 of Set 11 | montrose
# Processing Record 50 of Set 11 | chicama
# Processing Record 1 of Set 12 | qingdao
# Processing Record 2 of Set 12 | zhangye
# Processing Record 3 of Set 12 | grand island
# Processing Record 4 of Set 12 | elizabethtown
# Processing Record 5 of Set 12 | inuvik
# Processing Record 6 of Set 12 | saint-pierre
# Processing Record 7 of Set 12 | eyl
# Processing Record 8 of Set 12 | mackay
# Processing Record 9 of Set 12 | yala
# Processing Record 10 of Set 12 | carutapera
# Processing Record 11 of Set 12 | martapura
# Processing Record 12 of Set 12 | kununurra
# Processing Record 13 of Set 12 | jaguaruna
# Processing Record 14 of Set 12 | sisimiut
# Processing Record 15 of Set 12 | hualmay
# Processing Record 16 of Set 12 | neryungri
# Processing Record 17 of Set 12 | zaysan
# Processing Record 18 of Set 12 | muttupet
# Processing Record 19 of Set 12 | boguchar
# Processing Record 20 of Set 12 | yarada
# Processing Record 21 of Set 12 | lapeer
# Processing Record 22 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 23 of Set 12 | muzhi
# Processing Record 24 of Set 12 | qaqortoq
# Processing Record 25 of Set 12 | watsa
# Processing Record 26 of Set 12 | gizo
# Processing Record 27 of Set 12 | stornoway
# Processing Record 28 of Set 12 | roebourne
# Processing Record 29 of Set 12 | nong bua
# Processing Record 30 of Set 12 | acarau
# Processing Record 31 of Set 12 | kambove
# Processing Record 32 of Set 12 | laguna
# Processing Record 33 of Set 12 | florence
# Processing Record 34 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 35 of Set 12 | seoul
# Processing Record 36 of Set 12 | sarandi
# Processing Record 37 of Set 12 | aksarka
# Processing Record 38 of Set 12 | isangel
# Processing Record 39 of Set 12 | daultala
# Processing Record 40 of Set 12 | verkhnyaya sinyachikha
# Processing Record 41 of Set 12 | valparaiso
# Processing Record 42 of Set 12 | bertoua
# Processing Record 43 of Set 12 | alipur duar
# City not found. Skipping...
# Processing Record 44 of Set 12 | alta floresta
# Processing Record 45 of Set 12 | neiafu
# Processing Record 46 of Set 12 | izoplit
# Processing Record 47 of Set 12 | mirnyy
# Processing Record 48 of Set 12 | rapar
# Processing Record 49 of Set 12 | yeniseysk
# Processing Record 50 of Set 12 | adamclisi
# Processing Record 1 of Set 13 | baherden
# Processing Record 2 of Set 13 | manta
# Processing Record 3 of Set 13 | takoradi
# Processing Record 4 of Set 13 | oropesa
# Processing Record 5 of Set 13 | kothapet
# Processing Record 6 of Set 13 | marawi
# Processing Record 7 of Set 13 | sumenep
# Processing Record 8 of Set 13 | penzance
# Processing Record 9 of Set 13 | pitimbu
# Processing Record 10 of Set 13 | pochutla
# Processing Record 11 of Set 13 | ostrovnoy
# Processing Record 12 of Set 13 | santa isabel do rio negro
# Processing Record 13 of Set 13 | horizontina
# Processing Record 14 of Set 13 | achi
# Processing Record 15 of Set 13 | san cristobal
# Processing Record 16 of Set 13 | lubbock
# Processing Record 17 of Set 13 | urucara
# Processing Record 18 of Set 13 | camacha
# Processing Record 19 of Set 13 | bourail
# Processing Record 20 of Set 13 | pingliang
# Processing Record 21 of Set 13 | racale
# Processing Record 22 of Set 13 | oranjemund
# Processing Record 23 of Set 13 | kirakira
# Processing Record 24 of Set 13 | paro
# Processing Record 25 of Set 13 | sindou
# Processing Record 26 of Set 13 | kristianstad
# Processing Record 27 of Set 13 | murdochville
# Processing Record 28 of Set 13 | narsingdi
# Processing Record 29 of Set 13 | mandalgovi
# Processing Record 30 of Set 13 | oreanda
# City not found. Skipping...
# Processing Record 31 of Set 13 | rezh
# Processing Record 32 of Set 13 | edgewater
# Processing Record 33 of Set 13 | aldan
# Processing Record 34 of Set 13 | maykop
# Processing Record 35 of Set 13 | yefira
# City not found. Skipping...
# Processing Record 36 of Set 13 | mantua
# Processing Record 37 of Set 13 | arlit
# Processing Record 38 of Set 13 | miquelon
# Processing Record 39 of Set 13 | salsk
# Processing Record 40 of Set 13 | bandarbeyla
# Processing Record 41 of Set 13 | mehamn
# Processing Record 42 of Set 13 | buluang
# Processing Record 43 of Set 13 | baltasi
# Processing Record 44 of Set 13 | kerteh
# City not found. Skipping...
# Processing Record 45 of Set 13 | luangwa
# Processing Record 46 of Set 13 | sinnamary
# Processing Record 47 of Set 13 | mongo
# Processing Record 48 of Set 13 | howard springs
# Processing Record 49 of Set 13 | norfolk
# Processing Record 50 of Set 13 | warmbad
# Processing Record 1 of Set 14 | ereymentau
# Processing Record 2 of Set 14 | balaipungut
# Processing Record 3 of Set 14 | bethel
# Processing Record 4 of Set 14 | nishihara
# Processing Record 5 of Set 14 | lida
# Processing Record 6 of Set 14 | ksenyevka
# City not found. Skipping...
# Processing Record 7 of Set 14 | barra do corda
# Processing Record 8 of Set 14 | sioux lookout
# Processing Record 9 of Set 14 | dabat
# Processing Record 10 of Set 14 | jiuquan
# Processing Record 11 of Set 14 | lossiemouth
# Processing Record 12 of Set 14 | deer lake
# Processing Record 13 of Set 14 | terney
# Processing Record 14 of Set 14 | khandyga
# Processing Record 15 of Set 14 | novo aripuana
# Processing Record 16 of Set 14 | abu kamal
# Processing Record 17 of Set 14 | videira
# Processing Record 18 of Set 14 | abu samrah
# Processing Record 19 of Set 14 | ypsilanti
# Processing Record 20 of Set 14 | pimenteiras
# Processing Record 21 of Set 14 | hukuntsi
# Processing Record 22 of Set 14 | fengzhen
# Processing Record 23 of Set 14 | una
# Processing Record 24 of Set 14 | bayan
# Processing Record 25 of Set 14 | buin
# Processing Record 26 of Set 14 | breytovo
# Processing Record 27 of Set 14 | owando
# Processing Record 28 of Set 14 | nuuk
# Processing Record 29 of Set 14 | tutoia
# Processing Record 30 of Set 14 | bonavista
# Processing Record 31 of Set 14 | obo
# Processing Record 32 of Set 14 | bandhi
# Processing Record 33 of Set 14 | urfa
# City not found. Skipping...
# Processing Record 34 of Set 14 | riohacha
# Processing Record 35 of Set 14 | shakawe
# Processing Record 36 of Set 14 | husavik
# Processing Record 37 of Set 14 | walvis bay
# Processing Record 38 of Set 14 | weligama
# Processing Record 39 of Set 14 | yamada
# Processing Record 40 of Set 14 | tobol
# Processing Record 41 of Set 14 | tocopilla
# Processing Record 42 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 14 | san carlos de bariloche
# Processing Record 44 of Set 14 | gao
# Processing Record 45 of Set 14 | quzhou
# Processing Record 46 of Set 14 | mersing
# Processing Record 47 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 48 of Set 14 | gewane
# Processing Record 49 of Set 14 | elliot
# Processing Record 50 of Set 14 | mandal
# Processing Record 1 of Set 15 | caluquembe
# Processing Record 2 of Set 15 | brewster
# Processing Record 3 of Set 15 | fianga
# City not found. Skipping...
# Processing Record 4 of Set 15 | saleilua
# City not found. Skipping...
# Processing Record 5 of Set 15 | felidhoo
# City not found. Skipping...
# Processing Record 6 of Set 15 | dom pedro
# Processing Record 7 of Set 15 | myrhorod
# Processing Record 8 of Set 15 | menongue
# Processing Record 9 of Set 15 | ponta delgada
# Processing Record 10 of Set 15 | dandong
# Processing Record 11 of Set 15 | dapaong
# Processing Record 12 of Set 15 | manitouwadge
# Processing Record 13 of Set 15 | sidi ali
# Processing Record 14 of Set 15 | camaqua
# Processing Record 15 of Set 15 | kokkola
# Processing Record 16 of Set 15 | tonj
# Processing Record 17 of Set 15 | san felipe
# Processing Record 18 of Set 15 | constitucion
# Processing Record 19 of Set 15 | eirunepe
# Processing Record 20 of Set 15 | sorong
# Processing Record 21 of Set 15 | kankakee
# Processing Record 22 of Set 15 | taraz
# Processing Record 23 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 24 of Set 15 | payson
# Processing Record 25 of Set 15 | visby
# Processing Record 26 of Set 15 | dongzhen
# Processing Record 27 of Set 15 | tommot
# Processing Record 28 of Set 15 | amahai
# Processing Record 29 of Set 15 | cuenca
# Processing Record 30 of Set 15 | zhigalovo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 665

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Faanui -16.4833 -151.7500     79.36        74          28
# 1  Saint-Philippe -21.3585   55.7679     67.59        81          50
# 2           Bluff -46.6000  168.3333     48.81        60          61
# 3        Victoria  22.2855  114.1577     80.65        65          39
# 4       Mahebourg -20.4081   57.7000     71.26        88          75
# 5        Thompson  55.7435  -97.8558     30.36        69         100
# 6         Emerald -23.5333  148.1667     87.35        46          42
# 7        Hermanus -34.4187   19.2345     64.80        84          32
# 8           Vaini -21.2000 -175.2000     77.16        65          75
# 9    Puerto Ayora  -0.7393  -90.3518     66.54        89          90
#
#    Wind Speed Country       Description
# 0        8.10      PF  scattered clouds
# 1        9.42      RE  scattered clouds
# 2       15.35      NZ     broken clouds
# 3        8.99      HK  scattered clouds
# 4        3.44      MU     broken clouds
# 5        9.22      CA   overcast clouds
# 6       10.85      AU  scattered clouds
# 7       10.94      ZA  scattered clouds
# 8       17.27      TO     broken clouds
# 9        3.00      EC   overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Faanui      PF -16.4833 -151.7500     79.36        74          28
# 1  Saint-Philippe      RE -21.3585   55.7679     67.59        81          50
# 2           Bluff      NZ -46.6000  168.3333     48.81        60          61
# 3        Victoria      HK  22.2855  114.1577     80.65        65          39
# 4       Mahebourg      MU -20.4081   57.7000     71.26        88          75
# 5        Thompson      CA  55.7435  -97.8558     30.36        69         100
# 6         Emerald      AU -23.5333  148.1667     87.35        46          42
# 7        Hermanus      ZA -34.4187   19.2345     64.80        84          32
# 8           Vaini      TO -21.2000 -175.2000     77.16        65          75
# 9    Puerto Ayora      EC  -0.7393  -90.3518     66.54        89          90
#
#    Wind Speed       Description
# 0        8.10  scattered clouds
# 1        9.42  scattered clouds
# 2       15.35     broken clouds
# 3        8.99  scattered clouds
# 4        3.44     broken clouds
# 5        9.22   overcast clouds
# 6       10.85  scattered clouds
# 7       10.94  scattered clouds
# 8       17.27     broken clouds
# 9        3.00   overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label = "City_ID")
