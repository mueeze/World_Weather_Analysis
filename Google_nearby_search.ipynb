# %%
import requests
import gmaps

from config import g_key

# %%
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key, 
    "location": "23.8103, 90.4125"
}

# Use base URL to search for hotels in Dhaka
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make requests and get the JSON data from the search. 
hotels = requests.get(base_url, params = params).json()

hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'AcYSjRguVY516nCLx0CSznaJMPZjSZHoXPnNAUR4DcZfnimCQVcV5-7TaXzfuTX_gE5SYeMY2QgGQnqnqBkAA49CPoeVe00vw1s7pl8iPxjuHJZO73O8tOOuu_DxthWhLygZ9DlRGyU0GCPQRczrRYp4qvcrpgoF76d9XHuuGL2-OA8n88QIAYQi5p9UlVelB47EzopGSMjOU0uAaAw9KSNHBSIWDej2EE4RDOMrgXbgQx6GSjgW_1S7XP723wLNFcKkMweNpy8GBFNg8dpSIbe2H287wxCh868eaSy4WU6obMWRPwvAWm2SEt6dB64Fm17CLV22n4-Kzf_3UZObX30pjOPGGGQFOjHr_wTuh6rVu1M5HyPjG6TtZ1fcveK8sRCnje3jbkfbdozg1G39Ge5yC_k-MS8NJmeVp7gKKZfkRQsUENEUp2ZbWJSA',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 23.8293473, 'lng': 90.4194605},
#     'viewport': {'northeast': {'lat': 23.8307055802915,
#       'lng': 90.42088898029151},
#      'southwest': {'lat': 23.8280076197085, 'lng': 90.41819101970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Dhaka Regency Hotel & Resort',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 460,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102988157688212246157">ঢাকা রিজেন্সি হোটেল অ্যান্ড রিসোর্ট</a>'],
#      'photo_reference': 'AcYSjRhrDBKQHD5uG06lR7J7_ovnguHHjw5iqcVhjU4X64IuKeTTYUEg0r1sFLi61LQ-My9pn4MBujOoETjFgvZwymY0UVSiG6cDENMxf5cRXH8Zk1TtJ8wwGgpNDP72QOyk9ay4bpnhqRBF8cdJbeSjAdwO5MoDLQxrTFbMrCcsuVEh_CCY',
#      'width': 817}],
#    'place_id': 'ChIJCw5dYFzGVTcRX0HsF-ByEuk',
#    'plus_code': {'compound_code': 'RCH9+PQ Dhaka, Bangladesh',
#     'global_code': '7MMGRCH9+PQ'},
#    'rating': 4.3,
#    'reference': 'ChIJCw5dYFzGVTcRX0HsF-ByEuk',
#    'scope': 'GOOGLE',
#    'types': ['gym',
#     'bar',
#     'lodging',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'spa',
#     'health',
#     'establishment'],
#    'user_ratings_total': 6604,
#    'vicinity': 'Airport Rd, Dhaka'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 23.7922589, 'lng': 90.4066138},
#     'viewport': {'northeast': {'lat': 23.7936270302915,
#       'lng': 90.4078355802915},
#      'southwest': {'lat': 23.7909290697085, 'lng': 90.4051376197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Innotel Business Boutique Hotel',
#    'photos': [{'height': 3328,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112270443173735473767">Innotel Business Boutique Hotel</a>'],
#      'photo_reference': 'AcYSjRgfty3M17JHQctrCGY6ms_x1nD1n6aZ4JDXo0WNW1oNA0rj7m1VBH5swFu_gnkBgUwMxHxalb3dLbtJPue-YUDvN0vaMHeH52c9vs-G6DcoudaBeMpsQHX1Iwwtnnza9ETB4DX0mrplsiz9ojbR4kwuowDfeqWEh0kLbDN2oLb8EBn-',
#      'width': 4992}],
#    'place_id': 'ChIJPz0IIQzHVTcRVWBTF-rlSZ0',
#    'plus_code': {'compound_code': 'QCR4+WJ Dhaka, Bangladesh',
#     'global_code': '7MMGQCR4+WJ'},
#    'rating': 4,
#    'reference': 'ChIJPz0IIQzHVTcRVWBTF-rlSZ0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 493,
#    'vicinity': 'House-23, Block E, Road No 10, Banani Road, Dhaka'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 23.8136349, 'lng': 90.41521300000001},
#     'viewport': {'northeast': {'lat': 23.8149830802915,
#       'lng': 90.4165339802915},
#      'southwest': {'lat': 23.8122851197085, 'lng': 90.4138360197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Babylon Hotel & Serviced Apartment',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114158123765035130592">Babylon Hotel &amp; Serviced Apartment</a>'],
#      'photo_reference': 'AcYSjRh0qPoT3vW0F-RxbTKCo3GO3LP-NvQNUj8_2YLz2ij9fZElBckWXmJy-CBnaSf_XhqY6qG3a2vvv0z6c8D49Fqn_tvJZfO54Q13SPMTd82myggyvjtQAMi_Age1oPD4ASR5Pnmo6_yqAeaARycW0EvWIkgxzSDi16Pmge7j1OWtlwVA',
#      'width': 5312}],
#    'place_id': 'ChIJ179kV1TGVTcRPtlJiy3YN2A',
#    'plus_code': {'compound_code': 'RC78+F3 Dhaka, Bangladesh',
#     'global_code': '7MMGRC78+F3'},
#    'rating': 4.1,
#    'reference': 'ChIJ179kV1TGVTcRPtlJiy3YN2A',
#    'scope': 'GOOGLE',
#    'types': ['travel_agency',
#     'real_estate_agency',
#     'car_rental',
#     'lodging',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 165,
#    'vicinity': 'Babylon Hotel, House 319 ইস্টার্ন রোড, ঢাকা'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 23.801001, 'lng': 90.41338069999999},
#     'viewport': {'northeast': {'lat': 23.8022881802915,
#       'lng': 90.4147520802915},
#      'southwest': {'lat': 23.7995902197085, 'lng': 90.4120541197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Nascent Gardenia Suites',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3344,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111991785326892815097">Nascent Gardenia Suites</a>'],
#      'photo_reference': 'AcYSjRjg-V7dpBMOsZ_ldmeAQh009quaY1YS-OgrmBvNmRH1_o_Utw8d1t2gvjGGPbgBasx40zDkmPjoffoC1yU2uxiz7at6jwRWxngtOmjBAqMjT-NLJaSQGBr82pbFM8olDkznBAJtvQMHnyNE5F4mAjnm0_ReRjGAiIdybuDDB_6as2v3',
#      'width': 4693}],
#    'place_id': 'ChIJtQ5OMajHVTcRAtH14cwRqJw',
#    'plus_code': {'compound_code': 'RC27+C9 Dhaka, Bangladesh',
#     'global_code': '7MMGRC27+C9'},
#    'rating': 4.2,
#    'reference': 'ChIJtQ5OMajHVTcRAtH14cwRqJw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 136,
#    'vicinity': 'House No - 28, Road No - 83, Gulshan circle - 2, Gulshan Diplomatic zone Dhaka'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 23.7932655, 'lng': 90.4043303},
#     'viewport': {'northeast': {'lat': 23.79454938029151,
#       'lng': 90.40566968029151},
#      'southwest': {'lat': 23.7918514197085, 'lng': 90.4029717197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Sarina Dhaka',
#    'photos': [{'height': 927,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102468731678954385091">Hotel Sarina Dhaka</a>'],
#      'photo_reference': 'AcYSjRiA5F--mGoB_K56O_BdWuqx8KTjFN2OI40XjvGtn-8DPc4aDzLLNlWHjYoxLaJBJzssETGSXlh0kp7KxDGBpYiDS4ivKC3thfkzyLLVpWhkht3QgKq3d9Dp3cKVXCGSSN6gDPzK6V1wSgt9tGq35uYThGNsNroANKvCpm5_wjG3Kqg',
#      'width': 771}],
#    'place_id': 'ChIJc-vsbw7HVTcR3MoAoofTxMc',
#    'plus_code': {'compound_code': 'QCV3+8P Dhaka, Bangladesh',
#     'global_code': '7MMGQCV3+8P'},
#    'rating': 4.3,
#    'reference': 'ChIJc-vsbw7HVTcR3MoAoofTxMc',
#    'scope': 'GOOGLE',
#    'types': ['cafe',
#     'lodging',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 4049,
#    'vicinity': 'Plot #27, Road #17, Banani C/A, Dhaka'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 23.7894399, 'lng': 90.41334680000001},
#     'viewport': {'northeast': {'lat': 23.7907638302915,
#       'lng': 90.41462363029153},
#      'southwest': {'lat': 23.7880658697085, 'lng': 90.41192566970851}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Tropical Daisy',
#    'photos': [{'height': 3840,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110242101723524532338">Hotel Tropical Daisy By Lifestyle Hotel BD Ltd</a>'],
#      'photo_reference': 'AcYSjRjaax6_KYQfp1p4Xya706hhAQz62fbtj1a_vcRo6wPm7MZn4yNPSZ--3ewB0nqCFHbZJF37StLY-St4shXw27MH8KB54XYrFk_vNmNPxuHJIBnr3t0Rb2P4Uf3Dhifa6dbNz8MMWqSeNnGCrsMnXA8lV8TWZOl-YU8vvQBv0i-Ae_1l',
#      'width': 5760}],
#    'place_id': 'ChIJi4YvlKDHVTcRQpnnA8Ip6vA',
#    'plus_code': {'compound_code': 'QCQ7+Q8 Dhaka, Bangladesh',
#     'global_code': '7MMGQCQ7+Q8'},
#    'rating': 4.1,
#    'reference': 'ChIJi4YvlKDHVTcRQpnnA8Ip6vA',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 898,
#    'vicinity': '2, House, 31/B Road Number 35/A, Dhaka'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 23.7947032, 'lng': 90.4193777},
#     'viewport': {'northeast': {'lat': 23.7959953802915,
#       'lng': 90.4207762802915},
#      'southwest': {'lat': 23.79329741970849, 'lng': 90.4180783197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Six Seasons Hotel',
#    'photos': [{'height': 1000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107668075275098283744">Six Seasons Hotel</a>'],
#      'photo_reference': 'AcYSjRjkc6GOaD7Y0jGGZb7MjgKaFNKNBlymdW0RmOV3UofEajD_0-1xY4S6sDNxwVehi10VwfV0mYaz4Kh8El_-HclWEHYnfoBqnfSMMP64kqn90LkBnFJKZJewSZt15NP6vU-ZJ1JkYaJEFvans2LMgUcnO9yUIr8d_XV4zMYgElnzs2CI',
#      'width': 1500}],
#    'place_id': 'ChIJsaQF96THVTcRrXMUCBVTCw4',
#    'plus_code': {'compound_code': 'QCV9+VQ Dhaka, Bangladesh',
#     'global_code': '7MMGQCV9+VQ'},
#    'rating': 4.3,
#    'reference': 'ChIJsaQF96THVTcRrXMUCBVTCw4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 5870,
#    'vicinity': 'Asha Concord, House No 19, Road No 96, Gulshan 2, Plot # 7, Block # NW(J Road No 51, Dhaka'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 23.7934126, 'lng': 90.4074624},
#     'viewport': {'northeast': {'lat': 23.79481723029151,
#       'lng': 90.40882048029151},
#      'southwest': {'lat': 23.7921192697085, 'lng': 90.40612251970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Sweet Dream',
#    'photos': [{'height': 2250,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112968557163452069373">Md. Jahirul Islam</a>'],
#      'photo_reference': 'AcYSjRjRjXDrBlTWXk7BVq83Yrn324XC0FSMEBEUF7e52VS6U57NyJ4yEUVsX62N5Mia5L6yYtZAgSVfbXsVXCnkoxbQwWLp2OcPkBsGDLq3z4o4ouyTjVb8cquDvlen8eUrmr07vHzgh5qDykHAoZkpaoXlUOzx10iyUTZ9GlROzb5QPRrg',
#      'width': 4000}],
#    'place_id': 'ChIJUWGMsw7HVTcR7W_NDw0_4GI',
#    'plus_code': {'compound_code': 'QCV4+9X Dhaka, Bangladesh',
#     'global_code': '7MMGQCV4+9X'},
#    'rating': 3.9,
#    'reference': 'ChIJUWGMsw7HVTcR7W_NDw0_4GI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 269,
#    'vicinity': '60 Kemal Ataturk Avenue, Dhaka'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 23.8047347, 'lng': 90.4196269},
#     'viewport': {'northeast': {'lat': 23.8061176302915,
#       'lng': 90.4209661802915},
#      'southwest': {'lat': 23.8034196697085, 'lng': 90.4182682197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Ascott The Residence Dhaka',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1664,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112527129445885425709">Ascott The Residence Dhaka</a>'],
#      'photo_reference': 'AcYSjRiQEdiEwbXSlJ4znJ5i8kF3AvIVM6lXHY2tQOSZuB6P5kFmLmzbxTbR6JorqU5lV3x6BROp3gZYhvSMriN68vN0sRdhxxgHFxBvuIMS6h9swCrXG4j3w6gKK-5aIAO-lqiO4U-FcQCvCELlebiFEJVhMIC2bqGD6qa6pRNfr5BPwjFm',
#      'width': 2496}],
#    'place_id': 'ChIJC-6J1K3HVTcR6FHdk7DdYdE',
#    'plus_code': {'compound_code': 'RC39+VV Dhaka, Bangladesh',
#     'global_code': '7MMGRC39+VV'},
#    'rating': 4.3,
#    'reference': 'ChIJC-6J1K3HVTcR6FHdk7DdYdE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 615,
#    'vicinity': 'Baridhara Diplomatic Zone, House 13 Road 8'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 23.7897094, 'lng': 90.4204831},
#     'viewport': {'northeast': {'lat': 23.7910685302915,
#       'lng': 90.4219006302915},
#      'southwest': {'lat': 23.7883705697085, 'lng': 90.4192026697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Long Beach Suites Dhaka',
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117256863841940082676">Rimel Ahmod</a>'],
#      'photo_reference': 'AcYSjRjH7WRV-2NfLaOT2U-dKyEdSzw7rdF5LGUYOcoB7Kde8ncxotf15RwUPeKp1q2M3WrhrNdXIjcjdTIpjFyGlnv4hpb8lWvrP9vDe3tlRw0cCjCvDl6fq3-scxfpvHWaUgkSr1YpUJvnsvNYdwnRyOd084r-8j-WPmMPE9zWaASe_Pls',
#      'width': 3264}],
#    'place_id': 'ChIJqZgacKPHVTcRRbpOGXvrJVc',
#    'plus_code': {'compound_code': 'QCQC+V5 Dhaka, Bangladesh',
#     'global_code': '7MMGQCQC+V5'},
#    'rating': 4.3,
#    'reference': 'ChIJqZgacKPHVTcRRbpOGXvrJVc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2670,
#    'vicinity': '4g, Winter Garden, House # CEN 4 (G), Road # 104 Gulshan-2 ঢাকা 1212 BD, 2 Road 104, Dhaka'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 23.7917769, 'lng': 90.4030567},
#     'viewport': {'northeast': {'lat': 23.7931152802915,
#       'lng': 90.4044834802915},
#      'southwest': {'lat': 23.7904173197085, 'lng': 90.4017855197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Orchard Suites',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4096,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108824903055151976190">Deelara Khan</a>'],
#      'photo_reference': 'AcYSjRhm5McFDZ0Vp7kwKcUXw74OHDDbtOQGMhKkN-rI1Zq_g2YPl-XTyh2VurIK757Z632qVM34sNESjk0mDu-PdK6JAJIKvQsnZk0_8ANCKSRrMdTCZbvqoxH2f8dYSOtRzkLfx5QDr4k4Ip04jFY6pjQA2S9-sOC4ZQ1xKwDlAtYu06eR',
#      'width': 3072}],
#    'place_id': 'ChIJmcZ-9w3HVTcRhjW1O-YYwTQ',
#    'plus_code': {'compound_code': 'QCR3+P6 Dhaka, Bangladesh',
#     'global_code': '7MMGQCR3+P6'},
#    'rating': 4,
#    'reference': 'ChIJmcZ-9w3HVTcRhjW1O-YYwTQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 631,
#    'vicinity': 'House No. 90, Block C, Road No 13A, Dhaka'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 23.8043131, 'lng': 90.4210974},
#     'viewport': {'northeast': {'lat': 23.8056721302915,
#       'lng': 90.4224958802915},
#      'southwest': {'lat': 23.8029741697085, 'lng': 90.41979791970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Nascent Gardenia Baridhara',
#    'photos': [{'height': 3456,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104182338924823651225">Rahat Raihan</a>'],
#      'photo_reference': 'AcYSjRiSjc6USc8J0JVVwvyzmjPEl2nRxuw_A5sdGvGTYJDQNJphgtf-gpWQJkobL_QwryN00dFu8ndmpa30FexOaMbW7VvCrbdwhJTCxj7hv6y_t14y2svhQgG1OApP6xtcMLKFKRMZQfSKlieHtTZrkUp0nWZqoXt2bDmALlm6m9_gTsz7',
#      'width': 4608}],
#    'place_id': 'ChIJ0Sr1Ca7HVTcRK4neGiw8FXA',
#    'plus_code': {'compound_code': 'RC3C+PC Dhaka, Bangladesh',
#     'global_code': '7MMGRC3C+PC'},
#    'rating': 4.1,
#    'reference': 'ChIJ0Sr1Ca7HVTcRK4neGiw8FXA',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 694,
#    'vicinity': 'Diplomatic Zone, 27 Park Road, Dhaka'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 23.79045600000001,
#      'lng': 90.41274229999999},
#     'viewport': {'northeast': {'lat': 23.7919228302915,
#       'lng': 90.4140833302915},
#      'southwest': {'lat': 23.7892248697085, 'lng': 90.4113853697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Amari Dhaka',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2301,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109923779461627637470">Amari Dhaka</a>'],
#      'photo_reference': 'AcYSjRjQVU0EHviHaPIvjtNpMZfP2x6Gsbsm4igsZbeFIbmNGyMAFUkAlJCS0uwY6MsA0wDyKEKXytB0qzCN7fgbeDVHzJ1xyFYBldEIb1huWgTVJ2kNTy0Khy74HdBJW2SKgShll-34xQrjA9wEUZplqI3XulnHMjLe_m-BGHBNAbUvURJ0',
#      'width': 3449}],
#    'place_id': 'ChIJ8dQQdgrHVTcRZ7w1R9D02HM',
#    'plus_code': {'compound_code': 'QCR7+53 Dhaka, Bangladesh',
#     'global_code': '7MMGQCR7+53'},
#    'rating': 4.5,
#    'reference': 'ChIJ8dQQdgrHVTcRZ7w1R9D02HM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 7438,
#    'vicinity': 'House No, 47 Road Number 41, Dhaka'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 23.81592969999999,
#      'lng': 90.40888300000002},
#     'viewport': {'northeast': {'lat': 23.8174684802915,
#       'lng': 90.41015993029153},
#      'southwest': {'lat': 23.8147705197085, 'lng': 90.4074619697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Radisson Blu Dhaka Water Garden',
#    'photos': [{'height': 1365,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109039614697148669918">Radisson Blu Dhaka Water Garden</a>'],
#      'photo_reference': 'AcYSjRgJX5KPHXDNa61jy_nxIuP3gI-WHXsoux3eAzxeOuBdhJoVTRMvCLrhwSRleWvMwegg9Cj43WKnbtFXQ1_VFQUX9OPXmd4LWvMi0h40MDC-PI68P5h4dCAWqDMhvKMGajR5WKY_ncTJtxDqUool9S-seM9HRDCWAsWQQmxaPkAzbDt2',
#      'width': 2048}],
#    'place_id': 'ChIJsbfBtv7GVTcRNAzF61UMNXY',
#    'plus_code': {'compound_code': 'RC85+9H Dhaka, Bangladesh',
#     'global_code': '7MMGRC85+9H'},
#    'rating': 4.5,
#    'reference': 'ChIJsbfBtv7GVTcRNAzF61UMNXY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 11212,
#    'vicinity': 'Airport Rd, Dhaka'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 23.7908573, 'lng': 90.412334},
#     'viewport': {'northeast': {'lat': 23.7921127302915,
#       'lng': 90.4136893302915},
#      'southwest': {'lat': 23.7894147697085, 'lng': 90.41099136970848}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Jatra Flagship Dhaka Lake View',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1920,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117238175050499232570">Keyaan Hassan</a>'],
#      'photo_reference': 'AcYSjRghsms0uY-FPhtQbdHYh4a8Eo1e7m_DftxFuT4xnquSGAf3iOftc4gx3TuxOwhR3K8d8mdlUDibcwJEtJa--eWmAwukXibf_ET6GjNwcWwwF2jo5qWtDql20CxVRo23ePbM_H4AWr2mLizvq-FSCsmEbnICT2TAOe0720dT7mymBV1x',
#      'width': 1080}],
#    'place_id': 'ChIJcSgsgEbHVTcRnf0xJJpcAg0',
#    'plus_code': {'compound_code': 'QCR6+8W Dhaka, Bangladesh',
#     'global_code': '7MMGQCR6+8W'},
#    'rating': 4.9,
#    'reference': 'ChIJcSgsgEbHVTcRnf0xJJpcAg0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 195,
#    'vicinity': 'Road Number 41, Dhaka'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 23.8196314, 'lng': 90.4330437},
#     'viewport': {'northeast': {'lat': 23.8209654802915,
#       'lng': 90.43439333029151},
#      'southwest': {'lat': 23.8182675197085, 'lng': 90.43169536970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Firoza Inn',
#    'photos': [{'height': 4160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100583046802667248242">Md Fahim</a>'],
#      'photo_reference': 'AcYSjRip4ZkfF8Gf0cSb5UX9GLYBaci9UjWvtkMN0kvzXcXTFNXDrSuccyLS8dcJAwoEHr3gNUkPIzJEaGkqilp49dCJ3kT5bJKSvVus6uoybM_fERbnRYAu1zXn9zAfaKAObHYaozr8K-guAH0j5L_BBFY3npYCZ30iJpyx8LMSWjvTKBXa',
#      'width': 3120}],
#    'place_id': 'ChIJR3yJsTfGVTcRioMGWHC-f8Y',
#    'plus_code': {'compound_code': 'RC9M+V6 Dhaka, Bangladesh',
#     'global_code': '7MMGRC9M+V6'},
#    'rating': 4.2,
#    'reference': 'ChIJR3yJsTfGVTcRioMGWHC-f8Y',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 6,
#    'vicinity': 'Road 13, Block: F House 458 Dhaka'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 23.793288, 'lng': 90.4147175},
#     'viewport': {'northeast': {'lat': 23.7947393802915,
#       'lng': 90.41604453029152},
#      'southwest': {'lat': 23.7920414197085, 'lng': 90.4133465697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'The Westin Dhaka',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109865875867226154258">Zubair Ahmed</a>'],
#      'photo_reference': 'AcYSjRhRSZAePwvn65QJDmvvRXh_S-jtah_9EICg3umSZF7XnVaKwysNn5SpQHOKgg5QzImKA5JRKlcK4rsRds0lh3KuCKvTGdaLpySo_dS0GJ__x8wn_RI1C9n9y26d6b_mj6oDXKsXV_E27beOnRNpN74awgxbqthO6ULBosZ9__OT3HGA',
#      'width': 4032}],
#    'place_id': 'ChIJg7sXL6fHVTcRJlDZL_aPGFc',
#    'plus_code': {'compound_code': 'QCV7+8V Dhaka, Bangladesh',
#     'global_code': '7MMGQCV7+8V'},
#    'rating': 4.5,
#    'reference': 'ChIJg7sXL6fHVTcRJlDZL_aPGFc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 13744,
#    'vicinity': 'Main Gulshan Avenue, Plot-01 সড়ক ৪৫, ঢাকা'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 23.7924309, 'lng': 90.40949669999999},
#     'viewport': {'northeast': {'lat': 23.7937852302915,
#       'lng': 90.4107874302915},
#      'southwest': {'lat': 23.7910872697085, 'lng': 90.40808946970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Amazon Lilly Lake View Residence',
#    'photos': [{'height': 3456,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116404272402327793068">Nazmul Islam</a>'],
#      'photo_reference': 'AcYSjRhuonAhI4bqJqqFYTHwwE8q0eCZ7Yf6X04twey9j2QTTB4n4IlKkWTima2rwUG_PfFLk8mNNa7PYHVaywXkLgO03Rjav4-ZrXlTdWfQEOtU5Jlu9NpQ6bOcXYSo1HmAuQgv5p-XA5AogRVdjeZWXfupniLWZE3zRcXRkNuIj1SFccA2',
#      'width': 4608}],
#    'place_id': 'ChIJ2RaiYgnHVTcRDCJLMHv66Cc',
#    'plus_code': {'compound_code': 'QCR5+XQ Dhaka, Bangladesh',
#     'global_code': '7MMGQCR5+XQ'},
#    'rating': 4.1,
#    'reference': 'ChIJ2RaiYgnHVTcRDCJLMHv66Cc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 395,
#    'vicinity': 'Block E, House 28 Road No. 19/A, Dhaka'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 23.79125, 'lng': 90.4057248},
#     'viewport': {'northeast': {'lat': 23.7926091802915,
#       'lng': 90.40700828029149},
#      'southwest': {'lat': 23.7899112197085, 'lng': 90.40431031970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Luminous The Residence',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3456,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111298427630668654989">Reservation Advisor</a>'],
#      'photo_reference': 'AcYSjRj0ktlnFE_5HTrA09D5uCCWV0OiGyBDR20bvYr2av4kzLE1PSFxpL5LMSWFXDrsjN0InpHKRRiOnvscBF91tGvIGmCND1v8friBpsxqpMkM_HelLE2U5WUO4-uKzRRfTxn232vRziAH4IESBz1sIQe5DJhijs5e675EDU54V_Y1yhqk',
#      'width': 5184}],
#    'place_id': 'ChIJ0wCNq1G_VTcRq3jUkhiUk-s',
#    'plus_code': {'compound_code': 'QCR4+F7 Dhaka, Bangladesh',
#     'global_code': '7MMGQCR4+F7'},
#    'rating': 3.4,
#    'reference': 'ChIJ0wCNq1G_VTcRq3jUkhiUk-s',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 8,
#    'vicinity': 'House 65, Road 15 Block D, Banani Bridge, Dhaka'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 23.79166889999999, 'lng': 90.4110218},
#     'viewport': {'northeast': {'lat': 23.7929637802915,
#       'lng': 90.4123756302915},
#      'southwest': {'lat': 23.79026581970849, 'lng': 90.40967766970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Lake View Plaza',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1752,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108251012321662432359">Hotel Lake View Plaza</a>'],
#      'photo_reference': 'AcYSjRhfcDhk4tZsqEFbt74HeLIcaooFzOjIOeNglWczeFP1GBGdyTM5YuYUgOu0gnX-QUjBzobN9BFAvAZ9k6_T6IAyToUwXEgZ2cojdhcO0xprxdTI5qKH125N7VsHvUTjPrB86nCCRk6d0-9P0Ij64Xxupc_H3VTVqnT_XwVivCCHiS3v',
#      'width': 1816}],
#    'place_id': 'ChIJwaVnOwrHVTcREchvK-mnMt0',
#    'plus_code': {'compound_code': 'QCR6+MC Dhaka, Bangladesh',
#     'global_code': '7MMGQCR6+MC'},
#    'rating': 3.9,
#    'reference': 'ChIJwaVnOwrHVTcREchvK-mnMt0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 272,
#    'vicinity': 'House no: 88, 16 Road No 43, Dhaka'}],
#  'status': 'OK'}

# %%
len(hotels["results"])
# Out:
# 20
